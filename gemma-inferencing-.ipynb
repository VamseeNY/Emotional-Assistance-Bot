# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# Load model and tokenizer
model_name = "vamsss/gemma-finetune-gguf"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.52.4

# %%
# Your existing inference code structure
tamil_input="வேலை மிகவும் மன அழுத்தமாகி வருகிறது. எனது எதிர்காலம் மற்றும் வேலையைப் பற்றி நான் கவலைப்படுகிறேன்"
messages = [
    {
        "role": "user",
        "content": "நீங்கள் ஒரு பயிற்சி பெற்ற மனநல ஆலோசகர். 50 வார்த்தைகளில் தெளிவான மற்றும் சுருக்கமான பதிலுடன் பயனரை ஆறுதல்படுத்துங்கள். பயனர்: " + tamil_input
    }
]

text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
)

inputs = tokenizer([text], return_tensors="pt").to("cpu")

outputs = model.generate(
    **inputs,
    max_new_tokens=300,
    temperature=0.5,
    top_p=0.95,
    top_k=64,
)

response = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]
print("Generated Response:")
print(response)
# Out:
# Generated Response:
# user
# நீங்கள் ஒரு பயிற்சி பெற்ற மனநல ஆலோசகர். 50 வார்த்தைகளில் தெளிவான மற்றும் சுருக்கமான பதிலுடன் பயனரை ஆறுதல்படுத்துங்கள். பயனர்: வேலை மிகவும் மன அழுத்தமாகி வருகிறது. எனது எதிர்காலம் மற்றும் வேலையைப் பற்றி நான் கவலைப்படுகிறேன்
# model
# உங்களுடைய கவலைகள் நியாயமானவை. வேலை அழுத்தம் மற்றும் எதிர்காலம் பற்றிய கவலைகள் மிகவும் இயல்பானவை. நீங்கள் தனியாக இல்லை என்பதை நினைவில் கொள்ளுங்கள். உங்கள் கவலைகளைப் பற்றி பேச உங்களுக்கு ஒரு நல்ல நண்பர் அல்லது ஆலோசகரை அணுகுவது முக்கியம். இந்த சூழ்நிலையில், உங்கள் மனதை அமைதிப்படுத்தவும், உங்கள் எண்ணங்களைச் சமாளிக்கவும், எதிர்காலத்திற்கான நம்பிக்கையை வளர்க்கவும், உங்களுக்கு ஆதரவாக இருக்கக்கூடிய ஒரு ஆலோசகரைத் தேடுங்கள்.
